# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPooling2D, UpSampling2D

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Functions

# %%
def plot_predictions(y_true, y_pred, shape, figsize):    
    f, ax = plt.subplots(2, y_true.shape[0], figsize=figsize)
    for i in range(y_true.shape[0]):
        ax[0][i].imshow(np.reshape(y_true[i], shape), aspect='auto')
        ax[1][i].imshow(np.reshape(y_pred[i], shape), aspect='auto')
    plt.tight_layout()

# %%
def make_autoencoder(input_shape, layers, latent_dim, activation, activation_out):
    inputs = tf.keras.Input(shape=input_shape)

    encoder = tf.keras.layers.Dense(layers[0], activation=activation)(inputs)
    for layer in layers[1:]:
        encoder = tf.keras.layers.Dense(layer, activation=activation)(encoder)
    encoder = tf.keras.layers.Dense(latent_dim, activation=activation)(encoder)
    simple_encoder = tf.keras.Model(inputs=[inputs], outputs=[encoder])

    decoder_inputs = tf.keras.layers.Input(shape=[latent_dim])
    decoder = tf.keras.layers.Dense(layers[::-1][0], activation=activation)(decoder_inputs)
    for layer in layers[::-1][1:]:
        decoder = tf.keras.layers.Dense(layer, activation=activation)(decoder)

    outputs = tf.keras.layers.Dense(input_shape[0], activation=activation_out)(decoder)
    simple_decoder = tf.keras.Model(inputs=[decoder_inputs], outputs=[outputs])

    latent = simple_encoder(inputs)
    reconstructions = simple_decoder(latent)
    model = tf.keras.Model(inputs=[inputs], outputs=[reconstructions])
    return model, simple_encoder

# %%
class sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var))*K.exp(log_var/2)+mean

# %%
def make_VAE(input_shape, layers, latent_dim, activation, activation_out):
    inputs = tf.keras.Input(shape=input_shape)
    encoder = tf.keras.layers.Dense(layers[0], activation=activation)(inputs)
    for layer in layers[1:]:
        encoder = tf.keras.layers.Dense(layer, activation=activation)(encoder)

    latent_mean = tf.keras.layers.Dense(latent_dim)(encoder) #Mean Encoding 
    latent_log_var = tf.keras.layers.Dense(latent_dim)(encoder) #LogVar Encoding
     
    latent_space = sampling()([latent_mean, latent_log_var])
    variational_encoder = tf.keras.Model(inputs=[inputs], outputs=[latent_mean, latent_log_var, latent_space])

    decoder_inputs = tf.keras.layers.Input(shape=[latent_dim])
    decoder = tf.keras.layers.Dense(layers[::-1][0], activation=activation)(decoder_inputs)
    for layer in layers[::-1][1:]:
        decoder = tf.keras.layers.Dense(layer, activation=activation)(decoder)

    outputs = tf.keras.layers.Dense(input_shape[0], activation=activation_out)(decoder)
    variational_decoder = tf.keras.Model(inputs=[decoder_inputs], outputs=[outputs])

    _, _, latent = variational_encoder(inputs)
    reconstructions = variational_decoder(latent)
    model = tf.keras.Model(inputs=[inputs], outputs=[reconstructions])

    latent_loss = -0.5 *K.sum(1 + latent_log_var - K.exp(latent_log_var) - K.square(latent_mean), axis=-1)
    vae_loss = K.mean(latent_loss)/np.prod(input_shape)
    model.add_loss(vae_loss)
    return model, variational_decoder

# %%
def plot_generated_samples(mat):
    n = mat.shape[0]
    fig, axes = plt.subplots(1, n, figsize = (20, 10))
    for image, ax in zip(mat, axes):
        ax.imshow(image)

# %%
def visualize_clean_vs_noisy(x, x_noise, num_images=5):
    plt.figure(figsize=(15, 5))  
    
    for i in range(num_images):
        index = np.random.randint(0, x.shape[0])

        # Display the clean image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(x[index])
        plt.title("Clean Image")
        plt.axis('off')  

        # Display the corresponding noisy image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(x_noise[index])
        plt.title("Noisy Image")
        plt.axis('off')  

    plt.tight_layout()  
    plt.show()

# %%
def make_conv_DAE(input_shape, layers, kernel_size, pooling_size, activation, activation_out, output):
    encoder_input = tf.keras.Input(shape=input_shape)
    x = Conv2D(layers[0], kernel_size, activation=activation, padding='same')(encoder_input)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pooling_size, padding='same')(x) 
    for layer in layers[1:]:
        x = Conv2D(layer, kernel_size, activation=activation, padding='same')(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D(pooling_size, padding='same')(x) 
    
    for layer in layers[::-1]:
        x = Conv2D(layer, kernel_size, activation=activation, padding='same')(x)
        x = BatchNormalization()(x)
        x = UpSampling2D()(x)
    decoded = Conv2D(output, kernel_size, activation=activation_out, padding='same')(x)
    model = tf.keras.Model(encoder_input, decoded)
    return model

# %%
def visualize_original_noise_reconstructed(autoencoder, x, x_noise, num_images=5):
    reconstructed_images = autoencoder.predict(x_noise)
    
    plt.figure(figsize=(25, 10)) 

    for i in range(num_images):
        #original image
        plt.subplot(3, num_images, i + 1)
        plt.imshow(x[i])
        plt.title("Original")
        plt.axis('off')

        # noisy image
        plt.subplot(3, num_images, num_images + i + 1)
        plt.imshow(x_noise[i])
        plt.title("Noisy")
        plt.axis('off') 

        #  reconstructed image
        plt.subplot(3, num_images, 2 * num_images + i + 1)
        plt.imshow(reconstructed_images[i])
        plt.title("Reconstructed")
        plt.axis('off')  

    plt.tight_layout()  
    plt.show()

# %% [markdown]
# # Prepare data

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255., x_test / 255.
x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])
x_train = x_train.astype(np.float32, copy=False)
x_test = x_test.astype(np.float32, copy=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# # Simple Autoencoder (AE)

# %%
model, encoder = make_autoencoder((784,), [512,128,32,8], 2, 'selu', 'sigmoid')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='mse')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5)
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %% [markdown]
# ## Train

# %%
history = model.fit(x=x_train, y=x_train, validation_split=0.2, batch_size=2048, epochs=1000, callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1651 - val_loss: 0.1219 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1089 - val_loss: 0.0818 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0773 - val_loss: 0.0659 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0633 - val_loss: 0.0572 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0557 - val_loss: 0.0511 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0502 - val_loss: 0.0477 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0474 - val_loss: 0.0460 - learning_rate: 1.0000e-04
# Epoch 8/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0459 - val_loss: 0.0448 - learning_rate: 1.0000e-04
# Epoch 9/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0447 - val_loss: 0.0439 - learning_rate: 1.0000e-04
# Epoch 10/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0437 - val_loss: 0.0430 - learning_rate: 1.0000e-04
# Epoch 11/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0429 - val_loss: 0.0422 - learning_rate: 1.0000e-04
# Epoch 12/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0420 - val_loss: 0.0415 - learning_rate: 1.0000e-04
# Epoch 13/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0414 - val_loss: 0.0408 - learning_rate: 1.0000e-04
# Epoch 14/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0408 - val_loss: 0.0403 - learning_rate: 1.0000e-04
# Epoch 15/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0403 - val_loss: 0.0398 - learning_rate: 1.0000e-04
# Epoch 16/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0397 - val_loss: 0.0394 - learning_rate: 1.0000e-04
# Epoch 17/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0393 - val_loss: 0.0390 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0390 - val_loss: 0.0388 - learning_rate: 1.0000e-04
# Epoch 19/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0387 - val_loss: 0.0385 - learning_rate: 1.0000e-04
# Epoch 20/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0386 - val_loss: 0.0382 - learning_rate: 1.0000e-04
# Epoch 21/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0381 - val_loss: 0.0381 - learning_rate: 1.0000e-04
# Epoch 22/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0381 - val_loss: 0.0378 - learning_rate: 1.0000e-04
# Epoch 23/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0378 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 24/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0377 - val_loss: 0.0373 - learning_rate: 1.0000e-04
# Epoch 25/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0372 - val_loss: 0.0370 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0370 - val_loss: 0.0368 - learning_rate: 1.0000e-04
# Epoch 27/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0367 - val_loss: 0.0365 - learning_rate: 1.0000e-04
# Epoch 28/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0364 - val_loss: 0.0363 - learning_rate: 1.0000e-04
# Epoch 29/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0364 - val_loss: 0.0361 - learning_rate: 1.0000e-04
# Epoch 30/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0361 - val_loss: 0.0359 - learning_rate: 1.0000e-04
# Epoch 31/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0359 - val_loss: 0.0357 - learning_rate: 1.0000e-04
# Epoch 32/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0357 - val_loss: 0.0356 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0356 - val_loss: 0.0355 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0354 - val_loss: 0.0353 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0352 - val_loss: 0.0352 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0351 - val_loss: 0.0351 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0350 - val_loss: 0.0349 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0349 - val_loss: 0.0348 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0348 - val_loss: 0.0347 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0347 - val_loss: 0.0346 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0345 - val_loss: 0.0345 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0344 - val_loss: 0.0344 - learning_rate: 1.0000e-04
# Epoch 43/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0344 - val_loss: 0.0343 - learning_rate: 1.0000e-04
# Epoch 44/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0343 - val_loss: 0.0341 - learning_rate: 1.0000e-04
# Epoch 45/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0341 - val_loss: 0.0340 - learning_rate: 1.0000e-04
# Epoch 46/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0340 - val_loss: 0.0339 - learning_rate: 1.0000e-04
# Epoch 47/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0340 - val_loss: 0.0339 - learning_rate: 1.0000e-04
# Epoch 48/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0337 - val_loss: 0.0337 - learning_rate: 1.0000e-04
# Epoch 49/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0336 - val_loss: 0.0337 - learning_rate: 1.0000e-04
# Epoch 50/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0336 - val_loss: 0.0336 - learning_rate: 1.0000e-04
# Epoch 51/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0334 - val_loss: 0.0335 - learning_rate: 1.0000e-04
# Epoch 52/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0335 - val_loss: 0.0334 - learning_rate: 1.0000e-04
# Epoch 53/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0332 - val_loss: 0.0333 - learning_rate: 1.0000e-04
# Epoch 54/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0333 - val_loss: 0.0332 - learning_rate: 1.0000e-04
# Epoch 55/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0331 - val_loss: 0.0331 - learning_rate: 1.0000e-04
# Epoch 56/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0329 - val_loss: 0.0330 - learning_rate: 1.0000e-04
# Epoch 57/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0329 - val_loss: 0.0329 - learning_rate: 1.0000e-04
# Epoch 58/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0326 - val_loss: 0.0328 - learning_rate: 1.0000e-04
# Epoch 59/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0327 - val_loss: 0.0327 - learning_rate: 1.0000e-04
# Epoch 60/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0326 - val_loss: 0.0326 - learning_rate: 1.0000e-04
# Epoch 61/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0324 - val_loss: 0.0325 - learning_rate: 1.0000e-04
# Epoch 62/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0322 - val_loss: 0.0324 - learning_rate: 1.0000e-04
# Epoch 63/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0322 - val_loss: 0.0323 - learning_rate: 1.0000e-04
# Epoch 64/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0321 - val_loss: 0.0322 - learning_rate: 1.0000e-04
# Epoch 65/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0321 - val_loss: 0.0321 - learning_rate: 1.0000e-04
# Epoch 66/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0319 - val_loss: 0.0320 - learning_rate: 1.0000e-04
# Epoch 67/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0317 - val_loss: 0.0319 - learning_rate: 1.0000e-04
# Epoch 68/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0318 - val_loss: 0.0318 - learning_rate: 1.0000e-04
# Epoch 69/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0316 - val_loss: 0.0318 - learning_rate: 1.0000e-04
# Epoch 70/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0315 - val_loss: 0.0317 - learning_rate: 1.0000e-04
# Epoch 71/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0314 - val_loss: 0.0316 - learning_rate: 1.0000e-04
# Epoch 72/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0316 - val_loss: 0.0315 - learning_rate: 1.0000e-04
# Epoch 73/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0313 - val_loss: 0.0314 - learning_rate: 1.0000e-04
# Epoch 74/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0312 - val_loss: 0.0314 - learning_rate: 1.0000e-04
# Epoch 75/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0312 - val_loss: 0.0313 - learning_rate: 1.0000e-04
# Epoch 76/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0311 - val_loss: 0.0312 - learning_rate: 1.0000e-04
# Epoch 77/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0310 - val_loss: 0.0312 - learning_rate: 1.0000e-04
# Epoch 78/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0309 - val_loss: 0.0311 - learning_rate: 1.0000e-04
# Epoch 79/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0310 - val_loss: 0.0310 - learning_rate: 1.0000e-04
# Epoch 80/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0307 - val_loss: 0.0310 - learning_rate: 1.0000e-04
# Epoch 81/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0306 - val_loss: 0.0309 - learning_rate: 1.0000e-04
# Epoch 82/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0306 - val_loss: 0.0309 - learning_rate: 1.0000e-04
# Epoch 83/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0306 - val_loss: 0.0308 - learning_rate: 1.0000e-04
# Epoch 84/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0305 - val_loss: 0.0308 - learning_rate: 1.0000e-04
# Epoch 85/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0304 - val_loss: 0.0307 - learning_rate: 1.0000e-04
# Epoch 86/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0306 - val_loss: 0.0306 - learning_rate: 1.0000e-04
# Epoch 87/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0304 - val_loss: 0.0306 - learning_rate: 1.0000e-04
# Epoch 88/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0302 - val_loss: 0.0306 - learning_rate: 1.0000e-04
# Epoch 89/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0303 - val_loss: 0.0305 - learning_rate: 1.0000e-04
# Epoch 90/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0300 - val_loss: 0.0304 - learning_rate: 1.0000e-04
# Epoch 91/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0301 - val_loss: 0.0304 - learning_rate: 1.0000e-04
# Epoch 92/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0302 - val_loss: 0.0303 - learning_rate: 1.0000e-04
# Epoch 93/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0300 - val_loss: 0.0303 - learning_rate: 1.0000e-04
# Epoch 94/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0301 - val_loss: 0.0302 - learning_rate: 1.0000e-04
# Epoch 95/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0301 - val_loss: 0.0302 - learning_rate: 1.0000e-04
# Epoch 96/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0299 - val_loss: 0.0302 - learning_rate: 1.0000e-04
# Epoch 97/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0300 - val_loss: 0.0301 - learning_rate: 1.0000e-04
# Epoch 98/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0298 - val_loss: 0.0300 - learning_rate: 1.0000e-04
# Epoch 99/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0298 - val_loss: 0.0301 - learning_rate: 1.0000e-04
# Epoch 100/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0298 - val_loss: 0.0300 - learning_rate: 1.0000e-04
# Epoch 101/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0297 - val_loss: 0.0299 - learning_rate: 1.0000e-04
# Epoch 102/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0295 - val_loss: 0.0299 - learning_rate: 1.0000e-04
# Epoch 103/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0296 - val_loss: 0.0299 - learning_rate: 1.0000e-04
# Epoch 104/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0296 - val_loss: 0.0298 - learning_rate: 1.0000e-04
# Epoch 105/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0294 - val_loss: 0.0298 - learning_rate: 1.0000e-04
# Epoch 106/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0295 - val_loss: 0.0297 - learning_rate: 1.0000e-04
# Epoch 107/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0293 - val_loss: 0.0297 - learning_rate: 1.0000e-04
# Epoch 108/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0295 - val_loss: 0.0297 - learning_rate: 1.0000e-04
# Epoch 109/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0294 - val_loss: 0.0296 - learning_rate: 1.0000e-04
# Epoch 110/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0295 - val_loss: 0.0296 - learning_rate: 1.0000e-04
# Epoch 111/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0293 - val_loss: 0.0295 - learning_rate: 1.0000e-04
# Epoch 112/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0292 - val_loss: 0.0295 - learning_rate: 1.0000e-04
# Epoch 113/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0291 - val_loss: 0.0295 - learning_rate: 1.0000e-04
# Epoch 114/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0293 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0291 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 116/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0290 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 117/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0289 - val_loss: 0.0293 - learning_rate: 1.0000e-04
# Epoch 118/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0290 - val_loss: 0.0293 - learning_rate: 1.0000e-04
# Epoch 119/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0289 - val_loss: 0.0293 - learning_rate: 1.0000e-04
# Epoch 120/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0290 - val_loss: 0.0292 - learning_rate: 1.0000e-04
# Epoch 121/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0290 - val_loss: 0.0292 - learning_rate: 1.0000e-04
# Epoch 122/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0287 - val_loss: 0.0292 - learning_rate: 1.0000e-04
# Epoch 123/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0288 - val_loss: 0.0292 - learning_rate: 1.0000e-04
# Epoch 124/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0289 - val_loss: 0.0291 - learning_rate: 1.0000e-04
# Epoch 125/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0287 - val_loss: 0.0291 - learning_rate: 1.0000e-04
# Epoch 126/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0287 - val_loss: 0.0291 - learning_rate: 1.0000e-04
# Epoch 127/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0288 - val_loss: 0.0291 - learning_rate: 1.0000e-04
# Epoch 128/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0286 - val_loss: 0.0290 - learning_rate: 1.0000e-04
# Epoch 129/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0286 - val_loss: 0.0290 - learning_rate: 1.0000e-04
# Epoch 130/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0286 - val_loss: 0.0290 - learning_rate: 1.0000e-04
# Epoch 131/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0285 - val_loss: 0.0289 - learning_rate: 1.0000e-04
# Epoch 132/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0284 - val_loss: 0.0289 - learning_rate: 1.0000e-04
# Epoch 133/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0285 - val_loss: 0.0289 - learning_rate: 1.0000e-04
# Epoch 134/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0285 - val_loss: 0.0289 - learning_rate: 1.0000e-04
# Epoch 135/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0286 - val_loss: 0.0289 - learning_rate: 1.0000e-04
# Epoch 136/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0286 - val_loss: 0.0288 - learning_rate: 8.0000e-05
# Epoch 137/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0285 - val_loss: 0.0288 - learning_rate: 8.0000e-05
# Epoch 138/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0284 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 139/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0284 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 140/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0283 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 141/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0284 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 142/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0284 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 143/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0282 - val_loss: 0.0287 - learning_rate: 8.0000e-05
# Epoch 144/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0283 - val_loss: 0.0286 - learning_rate: 8.0000e-05
# Epoch 145/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0284 - val_loss: 0.0286 - learning_rate: 8.0000e-05
# Epoch 146/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0282 - val_loss: 0.0286 - learning_rate: 8.0000e-05
# Epoch 147/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0283 - val_loss: 0.0286 - learning_rate: 6.4000e-05
# Epoch 148/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0282 - val_loss: 0.0286 - learning_rate: 6.4000e-05
# Epoch 149/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0282 - val_loss: 0.0286 - learning_rate: 6.4000e-05
# Epoch 150/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0286 - learning_rate: 6.4000e-05
# Epoch 151/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0282 - val_loss: 0.0285 - learning_rate: 6.4000e-05
# Epoch 152/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0285 - learning_rate: 6.4000e-05
# Epoch 153/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0282 - val_loss: 0.0285 - learning_rate: 5.1200e-05
# Epoch 154/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0285 - learning_rate: 5.1200e-05
# Epoch 155/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0285 - learning_rate: 5.1200e-05
# Epoch 156/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0281 - val_loss: 0.0285 - learning_rate: 5.1200e-05
# Epoch 157/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0282 - val_loss: 0.0284 - learning_rate: 5.1200e-05
# Epoch 158/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0283 - val_loss: 0.0284 - learning_rate: 5.1200e-05
# Epoch 159/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0281 - val_loss: 0.0284 - learning_rate: 5.1200e-05
# Epoch 160/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0280 - val_loss: 0.0284 - learning_rate: 4.0960e-05
# Epoch 161/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0281 - val_loss: 0.0284 - learning_rate: 4.0960e-05
# Epoch 162/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0281 - val_loss: 0.0284 - learning_rate: 4.0960e-05
# Epoch 163/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0279 - val_loss: 0.0284 - learning_rate: 4.0960e-05
# Epoch 164/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0280 - val_loss: 0.0284 - learning_rate: 4.0960e-05
# Epoch 165/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0284 - learning_rate: 3.2768e-05
# Epoch 166/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0280 - val_loss: 0.0284 - learning_rate: 3.2768e-05
# Epoch 167/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0280 - val_loss: 0.0284 - learning_rate: 3.2768e-05
# Epoch 168/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0279 - val_loss: 0.0284 - learning_rate: 3.2768e-05
# Epoch 169/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0280 - val_loss: 0.0283 - learning_rate: 3.2768e-05
# Epoch 170/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 3.2768e-05
# Epoch 171/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0281 - val_loss: 0.0283 - learning_rate: 3.2768e-05
# Epoch 172/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 2.6214e-05
# Epoch 173/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0280 - val_loss: 0.0283 - learning_rate: 2.6214e-05
# Epoch 174/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 2.6214e-05
# Epoch 175/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0280 - val_loss: 0.0283 - learning_rate: 2.6214e-05
# Epoch 176/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 2.6214e-05
# Epoch 177/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 2.0972e-05
# Epoch 178/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 2.0972e-05
# Epoch 179/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 2.0972e-05
# Epoch 180/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0280 - val_loss: 0.0283 - learning_rate: 2.0972e-05
# Epoch 181/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 2.0972e-05
# Epoch 182/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 183/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 184/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 185/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 186/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 187/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 188/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 189/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0283 - learning_rate: 1.6777e-05
# Epoch 190/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.6777e-05
# Epoch 191/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.6777e-05
# Epoch 192/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0280 - val_loss: 0.0282 - learning_rate: 1.3422e-05
# Epoch 193/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.3422e-05
# Epoch 194/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3422e-05
# Epoch 195/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.3422e-05
# Epoch 196/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3422e-05
# Epoch 197/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0737e-05
# Epoch 198/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.0737e-05
# Epoch 199/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.0737e-05
# Epoch 200/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.0737e-05
# Epoch 201/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0737e-05
# Epoch 202/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 8.5899e-06
# Epoch 203/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 8.5899e-06
# Epoch 204/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 8.5899e-06
# Epoch 205/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5899e-06
# Epoch 206/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5899e-06
# Epoch 207/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 6.8719e-06
# Epoch 208/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 6.8719e-06
# Epoch 209/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 6.8719e-06
# Epoch 210/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 6.8719e-06
# Epoch 211/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 6.8719e-06
# Epoch 212/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4976e-06
# Epoch 213/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4976e-06
# Epoch 214/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 5.4976e-06
# Epoch 215/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.4976e-06
# Epoch 216/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4976e-06
# Epoch 217/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.3980e-06
# Epoch 218/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.3980e-06
# Epoch 219/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0280 - val_loss: 0.0282 - learning_rate: 4.3980e-06
# Epoch 220/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.3980e-06
# Epoch 221/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.3980e-06
# Epoch 222/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.5184e-06
# Epoch 223/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.5184e-06
# Epoch 224/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.5184e-06
# Epoch 225/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.5184e-06
# Epoch 226/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.5184e-06
# Epoch 227/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.8147e-06
# Epoch 228/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.8147e-06
# Epoch 229/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.8147e-06
# Epoch 230/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 2.8147e-06
# Epoch 231/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.8147e-06
# Epoch 232/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2518e-06
# Epoch 233/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2518e-06
# Epoch 234/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2518e-06
# Epoch 235/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2518e-06
# Epoch 236/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.2518e-06
# Epoch 237/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.8014e-06
# Epoch 238/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.8014e-06
# Epoch 239/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.8014e-06
# Epoch 240/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.8014e-06
# Epoch 241/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.8014e-06
# Epoch 242/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4412e-06
# Epoch 243/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.4412e-06
# Epoch 244/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.4412e-06
# Epoch 245/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.4412e-06
# Epoch 246/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4412e-06
# Epoch 247/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.1529e-06
# Epoch 248/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1529e-06
# Epoch 249/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1529e-06
# Epoch 250/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.1529e-06
# Epoch 251/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1529e-06
# Epoch 252/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.2234e-07
# Epoch 253/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.2234e-07
# Epoch 254/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.2234e-07
# Epoch 255/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 9.2234e-07
# Epoch 256/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.2234e-07
# Epoch 257/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 7.3787e-07
# Epoch 258/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 7.3787e-07
# Epoch 259/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 7.3787e-07
# Epoch 260/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 7.3787e-07
# Epoch 261/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 7.3787e-07
# Epoch 262/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.9030e-07
# Epoch 263/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.9030e-07
# Epoch 264/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.9030e-07
# Epoch 265/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 5.9030e-07
# Epoch 266/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.9030e-07
# Epoch 267/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.7224e-07
# Epoch 268/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.7224e-07
# Epoch 269/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.7224e-07
# Epoch 270/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.7224e-07
# Epoch 271/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.7224e-07
# Epoch 272/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.7779e-07
# Epoch 273/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.7779e-07
# Epoch 274/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.7779e-07
# Epoch 275/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.7779e-07
# Epoch 276/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.7779e-07
# Epoch 277/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 3.0223e-07
# Epoch 278/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 3.0223e-07
# Epoch 279/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.0223e-07
# Epoch 280/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.0223e-07
# Epoch 281/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.0223e-07
# Epoch 282/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.4179e-07
# Epoch 283/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.4179e-07
# Epoch 284/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 2.4179e-07
# Epoch 285/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.4179e-07
# Epoch 286/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.4179e-07
# Epoch 287/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.9343e-07
# Epoch 288/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 1.9343e-07
# Epoch 289/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.9343e-07
# Epoch 290/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 1.9343e-07
# Epoch 291/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.9343e-07
# Epoch 292/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.5474e-07
# Epoch 293/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.5474e-07
# Epoch 294/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.5474e-07
# Epoch 295/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.5474e-07
# Epoch 296/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 1.5474e-07
# Epoch 297/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.2379e-07
# Epoch 298/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.2379e-07
# Epoch 299/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.2379e-07
# Epoch 300/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.2379e-07
# Epoch 301/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.2379e-07
# Epoch 302/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.9035e-08
# Epoch 303/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.9035e-08
# Epoch 304/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.9035e-08
# Epoch 305/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 9.9035e-08
# Epoch 306/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 9.9035e-08
# Epoch 307/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 7.9228e-08
# Epoch 308/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 7.9228e-08
# Epoch 309/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 7.9228e-08
# Epoch 310/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 7.9228e-08
# Epoch 311/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 7.9228e-08
# Epoch 312/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 6.3383e-08
# Epoch 313/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 6.3383e-08
# Epoch 314/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 6.3383e-08
# Epoch 315/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 6.3383e-08
# Epoch 316/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 6.3383e-08
# Epoch 317/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.0706e-08
# Epoch 318/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.0706e-08
# Epoch 319/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.0706e-08
# Epoch 320/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.0706e-08
# Epoch 321/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 5.0706e-08
# Epoch 322/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.0565e-08
# Epoch 323/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.0565e-08
# Epoch 324/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.0565e-08
# Epoch 325/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.0565e-08
# Epoch 326/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.0565e-08
# Epoch 327/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.2452e-08
# Epoch 328/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.2452e-08
# Epoch 329/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 3.2452e-08
# Epoch 330/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.2452e-08
# Epoch 331/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 3.2452e-08
# Epoch 332/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.5961e-08
# Epoch 333/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.5961e-08
# Epoch 334/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.5961e-08
# Epoch 335/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.5961e-08
# Epoch 336/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.5961e-08
# Epoch 337/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.0769e-08
# Epoch 338/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.0769e-08
# Epoch 339/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.0769e-08
# Epoch 340/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.0769e-08
# Epoch 341/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 2.0769e-08
# Epoch 342/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.6615e-08
# Epoch 343/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.6615e-08
# Epoch 344/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.6615e-08
# Epoch 345/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.6615e-08
# Epoch 346/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.6615e-08
# Epoch 347/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3292e-08
# Epoch 348/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3292e-08
# Epoch 349/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 1.3292e-08
# Epoch 350/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3292e-08
# Epoch 351/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.3292e-08
# Epoch 352/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.0634e-08
# Epoch 353/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0634e-08
# Epoch 354/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0634e-08
# Epoch 355/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0634e-08
# Epoch 356/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.0634e-08
# Epoch 357/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5071e-09
# Epoch 358/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5071e-09
# Epoch 359/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5071e-09
# Epoch 360/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5071e-09
# Epoch 361/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 8.5071e-09
# Epoch 362/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 6.8056e-09
# Epoch 363/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 6.8056e-09
# Epoch 364/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 6.8056e-09
# Epoch 365/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 6.8056e-09
# Epoch 366/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 6.8056e-09
# Epoch 367/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4445e-09
# Epoch 368/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4445e-09
# Epoch 369/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 5.4445e-09
# Epoch 370/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 5.4445e-09
# Epoch 371/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 5.4445e-09
# Epoch 372/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 4.3556e-09
# Epoch 373/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 4.3556e-09
# Epoch 374/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.3556e-09
# Epoch 375/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.3556e-09
# Epoch 376/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 4.3556e-09
# Epoch 377/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.4845e-09
# Epoch 378/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.4845e-09
# Epoch 379/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.4845e-09
# Epoch 380/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 3.4845e-09
# Epoch 381/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 3.4845e-09
# Epoch 382/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.7876e-09
# Epoch 383/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0279 - val_loss: 0.0282 - learning_rate: 2.7876e-09
# Epoch 384/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.7876e-09
# Epoch 385/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.7876e-09
# Epoch 386/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.7876e-09
# Epoch 387/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2301e-09
# Epoch 388/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.2301e-09
# Epoch 389/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 2.2301e-09
# Epoch 390/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2301e-09
# Epoch 391/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 2.2301e-09
# Epoch 392/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0276 - val_loss: 0.0282 - learning_rate: 1.7841e-09
# Epoch 393/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.7841e-09
# Epoch 394/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.7841e-09
# Epoch 395/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.7841e-09
# Epoch 396/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.7841e-09
# Epoch 397/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4272e-09
# Epoch 398/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.4272e-09
# Epoch 399/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4272e-09
# Epoch 400/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4272e-09
# Epoch 401/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.4272e-09
# Epoch 402/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0277 - val_loss: 0.0282 - learning_rate: 1.1418e-09
# Epoch 403/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1418e-09
# Epoch 404/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1418e-09
# Epoch 405/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0278 - val_loss: 0.0282 - learning_rate: 1.1418e-09

# %% [markdown]
# ## History

# %%
hist = {'loss': history.history['loss'], 'val_loss': history.history['val_loss']}
sns.lineplot(data=hist, palette='viridis')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.yscale('log')

# %% [markdown]
# ## Show results

# %%
y_true = x_test[:10]
y_pred = model.predict(y_true)
plot_predictions(y_true, y_pred, (28,28), (18,4))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 y_true = x_test[:10]
#       2 y_pred = model.predict(y_true)
# ----> 3 plot_predictions(y_true, y_pred, (28,28), (18,4))
#
# Cell In[3], line 5, in plot_predictions(y_true, y_pred, shape, figsize)
#       3 for i in range(y_true.shape[0]):
#       4     ax[0][i].imshow(np.reshape(y_true[i], shape), aspect='auto')
# ----> 5     ax[1][i].imshow(np.reshape(y_pred[i], shape), aspect='auto')
#       6 plt.tight_layout()
#
# File /opt/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File /opt/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 7840 into shape (28,28)

# %% [markdown]
# ## Dimensionality reduction comparison

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_train)

sns.scatterplot(x=x_pca[:,0], y=x_pca[:,1], hue=y_train)
# Out:
# <Axes: >

# %%
x_latent = encoder.predict(x_train)
sns.scatterplot(x=x_latent[:,0], y=x_latent[:,1], hue=y_train)
# Out:
# 1875/1875 [==============================] - 2s 952us/step
# <Axes: >

# %% [markdown]
# # Variational Autoencoders (VAE)

# %%
latent_dim = 128
model, variational_decoder = make_VAE((784,), [512,256], latent_dim, 'gelu', 'sigmoid')
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='mse')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5)
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 latent_dim = 128
# ----> 2 model, variational_decoder = make_VAE((784,), [512,256], latent_dim, 'gelu', 'sigmoid')
#       3 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='mse')
#       4 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5)
#
# Cell In[9], line 24, in make_VAE(input_shape, layers, latent_dim, activation, activation_out)
#      21 reconstructions = variational_decoder(latent)
#      22 model = tf.keras.Model(inputs=[inputs], outputs=[reconstructions])
# ---> 24 latent_loss = -0.5 *K.sum(1 + latent_log_var - K.exp(latent_log_var) - K.square(latent_mean), axis=-1)
#      25 vae_loss = K.mean(latent_loss)/np.prod(input_shape)
#      26 model.add_loss(vae_loss)
#
# File /opt/anaconda3/lib/python3.10/site-packages/keras/src/legacy/backend.py:860, in exp(x)
#     857 @keras_export("keras._legacy.backend.exp")
#     858 def exp(x):
#     859     """DEPRECATED."""
# --> 860     return tf.exp(x)
#
# File /opt/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File /opt/anaconda3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /opt/anaconda3/lib/python3.10/site-packages/keras/src/backend/common/keras_tensor.py:138, in KerasTensor.__tf_tensor__(self, dtype, name)
#     137 def __tf_tensor__(self, dtype=None, name=None):
# --> 138     raise ValueError(
#     139         "A KerasTensor cannot be used as input to a TensorFlow function. "
#     140         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#     141         "used when constructing Keras Functional models "
#     142         "or Keras Functions. You can only use it as input to a Keras layer "
#     143         "or a Keras operation (from the namespaces `keras.layers` "
#     144         "and `keras.operations`). "
#     145         "You are likely doing something like:\n\n"
#     146         "```\n"
#     147         "x = Input(...)\n"
#     148         "...\n"
#     149         "tf_fn(x)  # Invalid.\n"
#     150         "```\n\n"
#     151         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     152         "```\n"
#     153         "class MyLayer(Layer):\n"
#     154         "    def call(self, x):\n"
#     155         "        return tf_fn(x)\n\n"
#     156         "x = MyLayer()(x)\n"
#     157         "```\n"
#     158     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %% [markdown]
# ## Train

# %%
history = model.fit(x_train, x_train, epochs=1000, batch_size=2048, validation_data=(x_test, x_test), callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 2/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 3/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 4/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 5/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0277 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 6/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 1.1418e-09
# Epoch 7/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 9.1344e-10
# Epoch 8/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 9.1344e-10
# Epoch 9/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 9.1344e-10
# Epoch 10/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0280 - val_loss: 0.0280 - learning_rate: 9.1344e-10
# Epoch 11/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 9.1344e-10
# Epoch 12/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 7.3075e-10
# Epoch 13/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 7.3075e-10
# Epoch 14/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 7.3075e-10
# Epoch 15/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 7.3075e-10
# Epoch 16/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 7.3075e-10
# Epoch 17/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 5.8460e-10
# Epoch 18/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0279 - val_loss: 0.0280 - learning_rate: 5.8460e-10
# Epoch 19/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 5.8460e-10
# Epoch 20/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 5.8460e-10
# Epoch 21/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 5.8460e-10
# Epoch 22/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 4.6768e-10
# Epoch 23/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0278 - val_loss: 0.0280 - learning_rate: 4.6768e-10

# %% [markdown]
# ## History

# %%
hist = {'loss': history.history['loss'], 'val_loss': history.history['val_loss']}
sns.lineplot(data=hist, palette='viridis')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.yscale('log')

# %% [markdown]
# ## Generate samples

# %%
n_sample = 8
latent_space = tf.random.normal(shape = [n_sample, latent_dim])
images = variational_decoder.predict(latent_space).reshape(n_sample,28,28)        
plot_generated_samples(images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 n_sample = 8
#       2 latent_space = tf.random.normal(shape = [n_sample, latent_dim])
# ----> 3 images = variational_decoder.predict(latent_space).reshape(n_sample,28,28)
#       4 plot_generated_samples(images)
#
# NameError: name 'variational_decoder' is not defined

# %% [markdown]
# # Denoising Autoencoder (DAE)

# %% [markdown]
# ## Prepare and add noise on data

# %%
x_train = x_train.reshape((x_train.shape[0], 28,28,1))
x_test = x_test.reshape((x_test.shape[0], 28,28,1))

# %%
noise_factor = 0.1

x_train_noise = x_train + np.random.normal(0, noise_factor, (x_train.shape[0], 28,28,1))
x_test_noise = x_test + np.random.normal(0, noise_factor, (x_test.shape[0],28,28,1))

# %%
visualize_clean_vs_noisy(x_train, x_train_noise, num_images=8)

# %% [markdown]
# ## Make model

# %%
model = make_conv_DAE(input_shape=(28,28,1), layers=[64,32], kernel_size=(3,3), pooling_size=(2,2), 
                        activation='selu', activation_out='sigmoid', output=1)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='mse')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5)
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %% [markdown]
# ## Train

# %%
history = model.fit(x_train_noise, x_train, batch_size=2048, epochs=1000, 
                    validation_data=(x_test_noise, x_test), callbacks=[reduce_lr, early_stopping], verbose=1)
# Out:
# Epoch 1/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - loss: 0.0875 - val_loss: 0.0674 - learning_rate: 0.0010
# Epoch 2/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - loss: 0.0312 - val_loss: 0.0607 - learning_rate: 0.0010
# Epoch 3/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - loss: 0.0242 - val_loss: 0.0532 - learning_rate: 0.0010
# Epoch 4/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - loss: 0.0199 - val_loss: 0.0640 - learning_rate: 0.0010
# Epoch 5/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - loss: 0.0169 - val_loss: 0.0781 - learning_rate: 0.0010
# Epoch 6/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 0.0148 - val_loss: 0.0787 - learning_rate: 0.0010
# Epoch 7/1000
# 19/30 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 0.0135

# %% [markdown]
# ## History

# %%
hist = {'loss': history.history['loss'], 'val_loss': history.history['val_loss']}
sns.lineplot(data=hist, palette='viridis')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.yscale('log')

# %% [markdown]
# ## Show results

# %%
visualize_original_noise_reconstructed(model, x_test, x_test_noise, num_images=8)
# Out:
# 313/313 [==============================] - 1s 2ms/step
